# %%
import pandas

# %%
import requests

# %%
import pandas as pd

# %%
from bs4 import BeautifulSoup

# %%
response = requests.get("https://www.metmuseum.org/art/collection/search?showOnly=withImage%7CopenAccess&department=11&searchField=ArtistCulture&q=Gustave+Courbet")

# %%
response
# Out:
# <Response [200]>

# %%
html_string = response.text

# %%
print(html_string[:500] + "...")
# Out:
# <!DOCTYPE html><html lang="en" class="
# 				__variable_362d9d
# 				__variable_bfed6e
# 				__variable_56d10a
# 				__variable_1411e1
# 				__variable_f75c8b
# 				__variable_75d57f" data-sentry-component="RootLayout" data-sentry-source-file="layout.tsx"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1"/><link rel="preload" as="image" href="https://images.metmuseum.org/CRDImages/ep/mobile-large/DT1975.jpg"/><link rel="preload" as="image" href="https://images.m...

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
document = BeautifulSoup(html_string, "html.parser")

# %%
document
# Out:
# <!DOCTYPE html>
# <html class="__variable_362d9d __variable_bfed6e __variable_56d10a __variable_1411e1 __variable_f75c8b __variable_75d57f" data-sentry-component="RootLayout" data-sentry-source-file="layout.tsx" lang="en"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link as="image" href="https://images.metmuseum.org/CRDImages/ep/mobile-large/DT1975.jpg" rel="preload"/><link as="image" href="https://images.metmuseum.org/CRDImages/ep/mobile-large/DP-23236-001.jpg" rel="preload"/><link as="image" href="https://images.metmuseum.org/CRDImages/ep/mobile-large/DT1963.jpg" rel="preload"/><link as="image" href="https://images.metmuseum.org/CRDImages/ep/mobile-large/DT1967.jpg" rel="preload"/><link as="image" href="https://images.metmuseum.org/CRDImages/ep/mobile-large/DT1964.jpg" rel="preload"/><link data-precedence="next" href="/_next/static/css/05c2505592d96dca.css" rel="stylesheet"/><link data-precedence="next" href="/_next/static/css/f0da8d54799d2829.css" rel="stylesheet"/><link data-precedence="next" href="/_next/static/css/8528cb058329dfe3.css" rel="stylesheet"/><link data-precedence="next" href="/_next/static/css/5b0834eeef2f5349.css" rel="stylesheet"/><link data-precedence="next" href="/_next/static/css/edeb9234b308ef16.css" rel="stylesheet"/><link data-precedence="next" href="/_next/static/css/1dd32985c2b20677.css" rel="stylesheet"/><link data-precedence="next" href="/_next/static/css/820647c3efd28926.css" rel="stylesheet"/><link data-precedence="next" href="/_next/static/css/e8b170cd26bd417c.css" rel="stylesheet"/><link data-precedence="next" href="/_next/static/css/9aaa76d535edb6e7.css" rel="stylesheet"/><link data-precedence="next" href="/_next/static/css/bbb4296439567a30.css" rel="stylesheet"/><link as="script" fetchpriority="low" href="/_next/static/chunks/webpack-fe76767bd64881b1.js" rel="preload"/><script async="" src="/_next/static/chunks/1b2a2cd6-ee6ca760c9ec013a.js"></script><script async="" src="/_next/static/chunks/2868-9315a221a73530df.js"></script><script async="" src="/_next/static/chunks/main-app-7d7b6f0d79b68669.js"></script><script async="" src="/_next/static/chunks/9152-d872e1a71c282695.js"></script><script async="" src="/_next/static/chunks/5701-cdc43415bf7498bf.js"></script><script async="" src="/_next/static/chunks/5227-0805fc4f02e6b576.js"></script><script async="" src="/_next/static/chunks/4202-8afce368280d44be.js"></script><script async="" src="/_next/static/chunks/app/%5Blocale%5D/(navigation)/layout-6969bd7a83822162.js"></script><script async="" src="/_next/static/chunks/app/%5Blocale%5D/(navigation)/error-03d8e63397405c7a.js"></script><script async="" src="/_next/static/chunks/app/global-error-b862df794239868b.js"></script><script async="" src="/_next/static/chunks/app/%5Blocale%5D/layout-b9abed9c73aa8ad2.js"></script><script async="" src="/_next/static/chunks/9211-6be10be12667464e.js"></script><script async="" src="/_next/static/chunks/9687-5125c6c160db4f21.js"></script><script async="" src="/_next/static/chunks/5927-c83e23ad5a7a4d11.js"></script><script async="" src="/_next/static/chunks/1138-0fe96db244c77347.js"></script><script async="" src="/_next/static/chunks/772-9a067fa16d86e76d.js"></script><script async="" src="/_next/static/chunks/6601-d11a2bf616f2b7aa.js"></script><script async="" src="/_next/static/chunks/2418-ef21bbc7b7578675.js"></script><script async="" src="/_next/static/chunks/6218-9de5b090e5461671.js"></script><script async="" src="/_next/static/chunks/3210-1233a1e00d0588aa.js"></script><script async="" src="/_next/static/chunks/6084-a4ec39b64e67e4bb.js"></script><script async="" src="/_next/static/chunks/app/%5Blocale%5D/(navigation)/art/collection/page-83a9cccfb5162336.js"></script><script async="" src="/_next/static/chunks/app/%5Blocale%5D/error-9c1433ea1dde7aeb.js"></script><script async="" src="/_next/static/chunks/app/%5Blocale%5D/(navigation)/page-52c82ae20bb5b091.js"></script><script async="" src="/_next/static/chunks/2824-a794749ec77586 ...
# 			<a href="/about-the-met/policies-and-documents/open-access">Open Access policy</a>,
# 			you can freely copy, modify and distribute this image, even for commercial purposes.
# 		</div>
# <em>API</em>Public domain data for this object can also be accessed using the Met's
# 		<a href="https://metmuseum.github.io/" target="_new">Open Access API</a></div></div></div></li><li class="collection-search-app_showOption__iYibp"><input class="collection-search-app_showCheckbox__yv_Hm" id="NEprovenance" name="NEprovenance" type="checkbox" value="NEprovenance"/><label for="NEprovenance">Nazi-era provenance</label><div class="collection-search-tool-tip_wrapper__QOuBh" data-sentry-component="CollectionSearchToolTip" data-sentry-source-file="index.jsx" role="button" tabindex="0"><svg class="collection-search-tool-tip_icon__90hP1" data-sentry-element="InfoSVG" data-sentry-source-file="index.jsx" fill="none" height="1em" viewbox="0 0 18 19" width="1em" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M0 9.5c0 4.964 4.037 9 9 9 4.962 0 9-4.036 9-9 0-4.963-4.038-9-9-9-4.963 0-9 4.037-9 9m1.524 0c0-4.122 3.353-7.475 7.476-7.475 4.122 0 7.475 3.354 7.476 7.475 0 4.124-3.354 7.476-7.476 7.476-4.123 0-7.476-3.352-7.476-7.476" fill="currentColor" fill-rule="evenodd"></path><path d="M8.031 7.804h1.937v6.787H8.031zM9 6.872A1.23 1.23 0 1 0 9 4.41a1.23 1.23 0 0 0 0 2.462" fill="currentColor"></path></svg><div class="collection-search-tool-tip_modal__Dk6cl"><div class="collection-search-tool-tip_text__6tuIq">Objects with changed or unknown ownership in continental Europe between 1933-1945.
# 		<a href="/about-the-met/policies-and-documents/provenance-research-project">Learn more</a></div></div></div></li></ul></div></section></details></div></section><section class="collection-search-app_activeFilters__EH8YI"><button class="clearable-filters_clearableFilter__8iANM clearable-filters_activeFilter__XwIoS" value="11">European Paintings</button><button class="clearable-filters_clearableFilter__8iANM clearable-filters_activeFilter__XwIoS" value="withImage">Artworks With Image</button><button class="clearable-filters_clearableFilter__8iANM clearable-filters_activeFilter__XwIoS" value="openAccess">Open Access</button></section><section class="collection-search-app_sortResults__CkXi4"><div class="collection-search-app_totalResults__RpwGY">Showing <!-- -->31<!-- --> results<!-- --> for Gustave Courbet</div><div class="collection-search-app_sortControl__SjR8o"><span class="collection-search-app_sectionTitle__q6Hq9">Sort by:</span><div class="simple-select_selectWrapper__tKgqs" data-sentry-component="SimpleSelect" data-sentry-source-file="index.tsx"><select class="simple-select_select__ZzBSH" id="sort-by" name="sort-by"><option value="">Relevance</option><option value="Title">Title (a-z)</option><option value="TitleDesc">Title (z-a)</option><option value="DateDesc">Date (newest-oldest)</option><option value="Date">Date (oldest-newest)</option><option value="ArtistMaker">Artist/Maker (a-z)</option><option value="ArtistMakerDesc">Artist/Maker (z-a)</option><option value="AccessionNumber">Accession Number (0-9)</option><option value="AccessionNumberDesc">Accession Number (9-0)</option></select></div></div></section><section class="object-grid_grid__hKKqs" data-sentry-component="ObjectGrid" data-sentry-source-file="index.tsx"><figure class="collection-object_collectionObject__SuPct" data-sentry-component="CollectionObject" data-sentry-source-file="index.tsx"><div class="collection-object_imageWrapper__dUMo_"><a aria-hidden="true" class="redundant-link_redundantlink__b5TFR" data-sentry-component="RedundantLink" data-sentry-element="GTMLink" data-sentry-source-file="index.jsx" href="/en/art/collection/search/436015" tabindex="-1"></a><img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="eager" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DT1975.jpg"/></div><figcaption class="collection-object_caption__Wbhum" data-sentry-element="figcaption" data-sentry-source-file="index.tsx"><div class="collection-object_title__1MnJJ"><a class="collection-object_link__qM3YR" data-sentry-element="Link" data-sentry-source-file="index.tsx" href="/en/art/collection/search/436015" title="Louis Gueymard (1822–1880) as Robert le Diable">Louis Gueymard (1822–1880) as Robert le Diable</a></div><div class="collection-object_body__cW9co"><div class="collection-object_culture__BaSXn">Gustave Courbet</div><div>1857</div></div></figcaption></figure><figure class="collection-object_collectionObject__SuPct" data-sentry-component="CollectionObject" data-sentry-source-file="index.tsx"><div class="collection-object_imageWrapper__dUMo_"><a aria-hidden="true" class="redundant-link_redundantlink__b5TFR" data-sentry-component="RedundantLink" data-sentry-element="GTMLink" data-sentry-source-file="index.jsx" href="/en/art/collection/search/436001" tabindex="-1"></a><img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="eager" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DP-23236-001.jpg"/></div><figcaption class="collection-object_caption__Wbhum" data-sentry-element="figcaption" data-sentry-source-file="index.tsx"><div class="collection-object_title__1MnJJ"><a class="collection-object_link__qM3YR" data-sentry-element="Link" data-sentry-source-file="index.tsx" href="/en/art/collection/search/436001" title="Jo, La Belle Irlandaise">Jo, La Belle Irlandaise</a></div><div class="collection-object_body__cW9co"><div class="collection-object_culture__BaSXn">Gustave Courbet</div><div>186 ...

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
#find all the images of the collections
document.find_all("img")
# Out:
# [<img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="eager" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DT1975.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="eager" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DP-23236-001.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="eager" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DT1963.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="eager" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DT1967.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="eager" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DT1964.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DT2147.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DT1965.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DP-17680-001.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DP-15681-001.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DP-17408-001.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DT1958.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DT1960.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DT887.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DT1973.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DT1962.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DT1961.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DP-14936-031.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DT1968.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DP124050.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DP-25035-001.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DP302942.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DP-25139-001.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DP-24650-001.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DP302935.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DP-1275-001.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/EP1059.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DP290289.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DP302937.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/ep29.100.123.bw.R.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/ep29.100.121.bw.R.jpg"/>,
#  <img class="collection-object_image__XVQPm collection-object_gridView__8kZLF" loading="lazy" src="https://images.metmuseum.org/CRDImages/ep/mobile-large/DP-22882-001.jpg"/>]

# %%
#to find the title of the painting
document.find("h1").text
# Out:
# 'Search The Collection'

# %%
import requests
from bs4 import BeautifulSoup
import csv

# Function to extract artwork details from the Met's collection URL
def scrape_artwork_info(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Extracting the title
    title_tag = soup.find('h1', {'id': 'artwork__title'})
    title = ''
    if title_tag:
        title = title_tag.find('span', {'class': 'artwork__title__inset'})
        if title:
            title = title.get_text(strip=True)

# Extracting the artist name using the correct class
    artist = ''
    artist_tag = soup.find('span', {'class': 'artwork__artist__name'})
    if artist_tag:
        artist = artist_tag.get_text(strip=True)
    
    # Extracting the image URL
    image_url = ''
    image_tag = soup.find('div', {'id': 'artwork__image__wrapper'})
    if image_tag:
        image = image_tag.find('img')
        if image and 'src' in image.attrs:
            image_url = image.attrs['src']

    # Exclude entries with unwanted artist qualifiers
    exclude_keywords = ["Attributed to", "Style of", "Copy after"]
    if any(keyword in artist for keyword in exclude_keywords):
        print(f"Excluded due to artist qualifier: {artist}")
        return None  # Skip this entry if it matches exclude criteria

    # Exclude entries not matching the desired artist name
    if artist != "Gustave Courbet":
        print(f"Excluded: {artist} (Not Gustave Courbet)")
        return None  # Skip this entry if it's not by Gustave Courbet
    
    # Debugging outputs (can be commented out later)
    print(f"Title: {title}")
    print(f"Artist: {artist}")
    print(f"Image URL: {image_url}")
    
    return {
        'title': title,
        'artist': artist,
        'image_url': image_url
    }

# %%
# Function to extract artwork URLs from a search page
def get_artwork_links(search_url):
    response = requests.get(search_url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Extract all 'href' attributes from 'figure' tags
    artwork_links = []
    for figure in soup.find_all('figure'):
        a_tag = figure.find('a')  # Find the anchor tag inside the figure
        if a_tag and 'href' in a_tag.attrs:
            artwork_links.append(a_tag['href'])
    
    # Convert relative links to absolute URLs
    base_url = "https://www.metmuseum.org"
    artwork_links = [base_url + link for link in artwork_links if link.startswith('/')]
    
    return artwork_links

# %%
# URL of the search page for "Gustave Courbet"
search_url = "https://www.metmuseum.org/art/collection/search?q=Gustave+Courbet"

# Get dynamically extracted URLs
urls = get_artwork_links(search_url)
print(f"Found {len(urls)} artwork links.")

# Scrape data from the dynamically extracted URLs
artworks_data = []
for url in urls:
    artwork_info = scrape_artwork_info(url)
    if artwork_info:  # Exclude None entries
        artworks_data.append(artwork_info)
# Out:
# Found 40 artwork links.
# Title: After the Hunt
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436007/796196/main-image
# Title: Young Ladies of the Village
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/438820/796200/main-image
# Title: The Calm Sea
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436005/796206/main-image
# Title: The Young Bather
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436003/1819005/main-image
# Title: Marine: The Waterspout
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436006/796198/main-image
# Title: Louis Gueymard (1822–1880) as Robert le Diable
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436015/796208/main-image
# Title: Jo, La Belle Irlandaise
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436001/2065085/main-image
# Title: The Woman in the Waves
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436004/796628/main-image
# Title: The Source of the Loue
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436023/796197/main-image
# Title: Madame Auguste Cuoq (Mathilde Desportes, 1827–1910)
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436016/796193/main-image
# Title: Woman with a Parrot
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436002/1911933/main-image
# Title: Alphonse Promayet (1822–1872)
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436008/796191/main-image
# Title: Woman in a Riding Habit (L'Amazone)
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436024/796283/main-image
# Title: Madame Frederic Breyer (Fanny Hélène Van Bruyssel, 1830–1894)
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436000/1890224/main-image
# Title: Monsieur Suisse
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436017/796195/main-image
# Title: Hunting Dogs with Dead Hare
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436014/796194/main-image
# Title: The Fishing Boat
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436012/1857523/main-image
# Title: The Source
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436022/794471/main-image
# Excluded due to artist qualifier: Attributed toGustave Courbet
# Title: Portrait of a Man
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436019/796201/main-image
# Excluded: Marcellin Desboutin (Not Gustave Courbet)
# Title: The Deer
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436011/796730/main-image
# Title: A Brook in the Forest
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436010/1293315/main-image
# Title: The Sea
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436021/2115447/main-image
# Title: View of Ornans
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436025/2114873/main-image
# Title: The Homecoming
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/670748/1483526/restricted
# Title: Nude with Flowering Branch
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436018/1702338/main-image
# Title: A Brook in a Clearing (possibly "Brook, Valley of Fontcouverte; Study")
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436009/1293331/main-image
# Title: River and Rocks
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436020/1293306/main-image
# Title: The Hidden Brook
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/436013/851091/main-image
# Title: Self-Portrait
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/393509/757558/main-image
# Title: Young Communards in Prison (Les Fédérés à la Conciergerie)
# Artist: Gustave Courbet
# Image URL: https://collectionapi.metmuseum.org/api/collection/v1/iiif/338093/755239/main-image
# Excluded: Félix Bracquemond (Not Gustave Courbet)
# Excluded: Félix Bracquemond (Not Gustave Courbet)
# Excluded: Laurent Hotelin (Not Gustave Courbet)
# Excluded due to artist qualifier: Style ofGustave Courbet
# Excluded due to artist qualifier: Style ofGustave Courbet
# Excluded: Gustave Le Gray (Not Gustave Courbet)
# Excluded due to artist qualifier: Copy afterGustave Courbet
# Excluded: Gustave Le Gray (Not Gustave Courbet)

# %%
# Remove None entries from the data
artworks_data = [artwork for artwork in artworks_data if artwork is not None]


# Save data to CSV file
csv_filename = r"C:\Users\re99n\TheMetMuseum_GustaveCourbet\theMetMuseum_GustaveCourbet_Metadata_Fixed.csv"
fieldnames = ["title", "artist", "image_url"]

with open(csv_filename, "w", newline="", encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for artwork in artworks_data:
        writer.writerow(artwork)

print(f"Data has been saved to {csv_filename}")
# Out:
# Data has been saved to C:\Users\re99n\TheMetMuseum_GustaveCourbet\theMetMuseum_GustaveCourbet_Metadata_Fixed.csv

# %%
# The CSV file contains special characters and might have a BOM (Byte Order Mark),
# so we use 'utf-8-sig' encoding to ensure proper reading of the file without encoding issues.
df = pd.read_csv('C:/Users/re99n/TheMetMuseum_GustaveCourbet/theMetMuseum_GustaveCourbet_Metadata_Fixed.csv', encoding='utf-8-sig')

# Save it again as UTF-8-sig
df.to_csv('C:/Users/re99n/TheMetMuseum_GustaveCourbet/theMetMuseum_GustaveCourbet_Metadata_Final_fixed.csv', encoding='utf-8-sig', index=False)

# %%
import matplotlib.pyplot as plt

#Categories and titles
categories = {
    "Portraits": ["Louis Gueymard", "Jo, La Belle Irlandaise", "Madame Auguste Cuoq", 
                  "Alphonse Promayet", "Portrait of a Man", "Madame Frederic Breyer", "Monsieur Suisse", "Self-Portrait"],
    "Landscapes and Nature": ["The Source of the Loue", "A Brook in the Forest", "View of Ornans", 
                              "River and Rocks", "The Sea", "The Hidden Brook", 
                              "A Brook in a Clearing", "The Deer"],
    "Genre and Animal Studies": ["After the Hunt", "Hunting Dogs with Dead Hare", 
                                  "The Fishing Boat", "The Homecoming"],
    "Nudes and Figures": ["Young Ladies of the Village", "The Woman in the Waves", 
                          "The Young Bather", "Nude with Flowering Branch", 
                          "Woman in a Riding Habit", "Woman with a Parrot"],
    "Still Life": [],
    "Seascapes": ["Marine: The Waterspout", "The Calm Sea"]
}

# Count the number of artworks in each category
category_counts = {category: len(titles) for category, titles in categories.items()}

# Plot the bar chart
plt.figure(figsize=(10, 6))
plt.bar(category_counts.keys(), category_counts.values(), color='skyblue')
plt.xlabel("Categories")
plt.ylabel("Number of Artworks")
plt.title("Distribution of Gustave Courbet's Artworks by Category")
plt.xticks(rotation=45)
plt.show()

# Explanation
print("The chart shows the number of artworks in each category. Portraits and Landscapes are dominant, reflecting Courbet's focus on depicting human subjects & nature")
# Out:
# The chart shows the number of artworks in each category. Portraits and Landscapes are dominant, reflecting Courbet's focus on depicting human subjects & nature
